# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/houhiroshisakai/Documents/2019-20_pbp.csv')

# %%
df=df.rename(columns={'Date':'GameDate'})

# %%
df.set_index('GameDate', inplace=True)

# %%
df.head(10)
# Out:
#                                           URL GameType     Time WinningTeam
# GameDate
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR  \
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
# October 22 2019  /boxscores/201910220TOR.html  regular  8:00 PM         TOR
#
#                  Quarter  SecLeft AwayTeam
# GameDate
# October 22 2019        1      720      NOP  \
# ...

# %%
df.tail()
# Out:
#                                           URL GameType     Time WinningTeam
# GameDate
# October 11 2020  /boxscores/202010110MIA.html  playoff  7:30 PM         LAL  \
# October 11 2020  /boxscores/202010110MIA.html  playoff  7:30 PM         LAL
# October 11 2020  /boxscores/202010110MIA.html  playoff  7:30 PM         LAL
# October 11 2020  /boxscores/202010110MIA.html  playoff  7:30 PM         LAL
# October 11 2020  /boxscores/202010110MIA.html  playoff  7:30 PM         LAL
#
#                  Quarter  SecLeft AwayTeam
# GameDate
# October 11 2020        4       29      LAL  \
# October 11 2020        4       20      LAL
# October 11 2020        4       15      LAL
# October 11 2020        4        0      LAL
# October 11 2020        4        0      LAL
#
#                                                           AwayPlay  AwayScore
# GameDate
# October 11 2020                                                NaN        103  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 539265 entries, October 22 2019 to October 11 2020
# Data columns (total 39 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   URL                 539265 non-null  object
#  1   GameType            539265 non-null  object
#  2   Time                539265 non-null  object
#  3   WinningTeam         539265 non-null  object
#  4   Quarter             539265 non-null  int64
#  5   SecLeft             539265 non-null  int64
#  6   AwayTeam            539265 non-null  object
#  7   AwayPlay            272389 non-null  object
#  8   AwayScore           539265 non-null  int64
#  9   HomeTeam            539265 non-null  object
#  10  HomePlay            266868 non-null  object
#  11  HomeScore           539265 non-null  int64
#  12  Shooter             202397 non-null  object
#  13  ShotType            202397 non-null  object
#  14  ShotOutcome         202397 non-null  object
# ...

# %%
df.index
# Out:
# Index(['October 22 2019', 'October 22 2019', 'October 22 2019',
#        'October 22 2019', 'October 22 2019', 'October 22 2019',
#        'October 22 2019', 'October 22 2019', 'October 22 2019',
#        'October 22 2019',
#        ...
#        'October 11 2020', 'October 11 2020', 'October 11 2020',
#        'October 11 2020', 'October 11 2020', 'October 11 2020',
#        'October 11 2020', 'October 11 2020', 'October 11 2020',
#        'October 11 2020'],
#       dtype='object', name='GameDate', length=539265)

# %%
df.columns
# Out:
# Index(['URL', 'GameType', 'Time', 'WinningTeam', 'Quarter', 'SecLeft',
#        'AwayTeam', 'AwayPlay', 'AwayScore', 'HomeTeam', 'HomePlay',
#        'HomeScore', 'Shooter', 'ShotType', 'ShotOutcome', 'ShotDist',
#        'Assister', 'Blocker', 'FoulType', 'Fouler', 'Fouled', 'Rebounder',
#        'ReboundType', 'ViolationPlayer', 'ViolationType', 'TimeoutTeam',
#        'FreeThrowShooter', 'FreeThrowOutcome', 'FreeThrowNum', 'EnterGame',
#        'LeaveGame', 'TurnoverPlayer', 'TurnoverType', 'TurnoverCause',
#        'TurnoverCauser', 'JumpballAwayPlayer', 'JumpballHomePlayer',
#        'JumpballPoss', 'Unnamed: 40'],
#       dtype='object')

# %%
df.axes
# Out:
# [Index(['October 22 2019', 'October 22 2019', 'October 22 2019',
#         'October 22 2019', 'October 22 2019', 'October 22 2019',
#         'October 22 2019', 'October 22 2019', 'October 22 2019',
#         'October 22 2019',
#         ...
#         'October 11 2020', 'October 11 2020', 'October 11 2020',
#         'October 11 2020', 'October 11 2020', 'October 11 2020',
#         'October 11 2020', 'October 11 2020', 'October 11 2020',
#         'October 11 2020'],
#        dtype='object', name='GameDate', length=539265),
#  Index(['URL', 'GameType', 'Time', 'WinningTeam', 'Quarter', 'SecLeft',
#         'AwayTeam', 'AwayPlay', 'AwayScore', 'HomeTeam', 'HomePlay',
#         'HomeScore', 'Shooter', 'ShotType', 'ShotOutcome', 'ShotDist',
#         'Assister', 'Blocker', 'FoulType', 'Fouler', 'Fouled', 'Rebounder',
#         'ReboundType', 'ViolationPlayer', 'ViolationType', 'TimeoutTeam',
#         'FreeThrowShooter', 'FreeThrowOutcome', 'FreeThrowNum', 'EnterGame',
# ...

# %%
df.dtypes
# Out:
# URL                    object
# GameType               object
# Time                   object
# WinningTeam            object
# Quarter                 int64
# SecLeft                 int64
# AwayTeam               object
# AwayPlay               object
# AwayScore               int64
# HomeTeam               object
# HomePlay               object
# HomeScore               int64
# Shooter                object
# ShotType               object
# ShotOutcome            object
# ShotDist              float64
# Assister               object
# Blocker                object
# FoulType               object
# Fouler                 object
# Fouled                 object
# Rebounder              object
# ReboundType            object
# ViolationPlayer        object
# ViolationType          object
# TimeoutTeam            object
# FreeThrowShooter       object
# FreeThrowOutcome       object
# FreeThrowNum           object
# EnterGame              object
# LeaveGame              object
# ...

# %%
df.sort_index(axis=0, ascending=True)
# Out:
#                                            URL GameType     Time WinningTeam
# GameDate
# August 1 2020     /boxscores/202008010DEN.html  regular  1:00 PM         MIA  \
# August 1 2020     /boxscores/202008010LAC.html  regular  6:00 PM         LAC
# August 1 2020     /boxscores/202008010LAC.html  regular  6:00 PM         LAC
# August 1 2020     /boxscores/202008010LAC.html  regular  6:00 PM         LAC
# August 1 2020     /boxscores/202008010LAC.html  regular  6:00 PM         LAC
# ...                                        ...      ...      ...         ...
# September 9 2020  /boxscores/202009090BOS.html  playoff  6:30 PM         TOR
# September 9 2020  /boxscores/202009090BOS.html  playoff  6:30 PM         TOR
# September 9 2020  /boxscores/202009090BOS.html  playoff  6:30 PM         TOR
# September 9 2020  /boxscores/202009090BOS.html  playoff  6:30 PM         TOR
# September 9 2020  /boxscores/202009090DEN.html  playoff  9:00 PM         LAC
#
# ...
