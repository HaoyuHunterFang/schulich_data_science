# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder

# Preprocessing, Metrics
from sklearn import preprocessing
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
df = pd.read_excel('/Users/Desktop/project/SFD_data.xlsx')
df.head()
# Out:
#            X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 0 -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00  \
# 1 -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2 -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3 -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4 -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
#
#    OCC_YEAR OCC_MONTH   OCC_DOW  OCC_DOY  OCC_DAY  ...  OCC_TIME_RANGE
# 0      2004       May  Saturday      136       15  ...           Night  \
# 1      2004      July    Monday      208       26  ...         Evening
# 2      2004       May    Friday      135       14  ...       Afternoon
# 3      2004  December    Sunday      354       19  ...           Night
# 4      2004     April    Monday      103       12  ...         Evening
#
#   DIVISION DEATH  INJURIES  HOOD_158       NEIGHBOURHOOD_158 HOOD_140
# 0      D41     0         0       142            Woburn North      137  \
# 1      D23     0         0         1  West Humber-Clairville        1
# 2      D31     1         1        24             Black Creek       24
# 3      D51     1         0       168     Downtown Yonge East       75
# 4      D42     0         0       146            Malvern East      132
#
#             NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84
# 0                Woburn (137) -79.234955  43.781528
# 1  West Humber-Clairville (1) -79.618218  43.733547
# 2            Black Creek (24) -79.518759  43.769157
# 3  Church-Yonge Corridor (75) -79.378870  43.660665
# 4               Malvern (132) -79.212435  43.812075
#
# [5 rows x 21 columns]

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5707 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5707 non-null   float64
#  1   Y                  5707 non-null   float64
#  2   OBJECTID           5707 non-null   int64
#  3   EVENT_UNIQUE_ID    5707 non-null   object
#  4   OCC_DATE           5707 non-null   object
#  5   OCC_YEAR           5707 non-null   int64
#  6   OCC_MONTH          5707 non-null   object
#  7   OCC_DOW            5707 non-null   object
#  8   OCC_DOY            5707 non-null   int64
#  9   OCC_DAY            5707 non-null   int64
#  10  OCC_HOUR           5707 non-null   int64
#  11  OCC_TIME_RANGE     5707 non-null   object
#  12  DIVISION           5707 non-null   object
#  13  DEATH              5707 non-null   int64
#  14  INJURIES           5707 non-null   int64
#  15  HOOD_158           5707 non-null   object
#  16  NEIGHBOURHOOD_158  5707 non-null   object
#  17  HOOD_140           5707 non-null   object
#  18  NEIGHBOURHOOD_140  5707 non-null   object
#  19  LONG_WGS84         5707 non-null   float64
#  20  LAT_WGS84          5707 non-null   float64
# dtypes: float64(4), int64(7), object(10)
# memory usage: 936.4+ KB

# %%
df["DIVISION"].hist()
plt.title("Histogram of DIVISION")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %%
df["OCC_TIME_RANGE"].hist()
plt.title("Histogram of OCC_TIME_RANGE")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %%
#Convert "Year" column to datetime

year_count = df.groupby('OCC_YEAR').size()
print(year_count)
# Out:
# OCC_YEAR
# 2004    191
# 2005    262
# 2006    215
# 2007    207
# 2008    238
# 2009    252
# 2010    259
# 2011    227
# 2012    219
# 2013    204
# 2014    177
# 2015    288
# 2016    407
# 2017    392
# 2018    427
# 2019    492
# 2020    462
# 2021    409
# 2022    379
# dtype: int64

# %%
plt.plot(year_count.index, year_count.values, marker ='o') 
plt.xticks(year_count.index)
plt.xticks(rotation=45, ha ='right', fontsize=8) 
plt.xlabel('Year')
plt.ylabel('Number of SFD Cases') 
plt.title('SFD Cases per Year') 
plt.show()

# %%
season_period = {
    'January': 'Winter',
    'February': 'Winter', 
    'March': 'Spring', 
    'April': 'Spring', 
    'May': 'Spring', 
    'June': 'Summer', 
    'July': 'Summer', 
    'August': 'Summer', 
    'September': 'Autumn', 
    'October': 'Autumn', 
    'November': 'Autumn', 
    'December': 'Winter'
}


df['Season'] = df['OCC_MONTH'].map(season_period)
df["Season"].hist()
plt.title("Histogram of Season")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %%
season_count = df['Season'].value_counts()
plt.pie(season_count.values, labels = season_count.index, autopct='%1.1f%%') 
plt.title ('Seasons Period Distribution')
# Out:
# Text(0.5, 1.0, 'Seasons Period Distribution')

# %%
# select the 3 year's Shooting and Firearm Discharge data
df = df[df['OCC_YEAR'].isin([2015, 2016, 2017])]
df.head()
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 2451 -79.440752  43.697311      2452  GO-20151105533  2015/07/01 04:00:00+00  \
# 2452 -79.482066  43.726636      2453  GO-20152239926  2015/12/31 05:00:00+00
# 2453 -79.564077  43.652450      2454   GO-2015484508  2015/03/23 04:00:00+00
# 2454 -79.542128  43.750842      2455  GO-20151170722  2015/07/11 04:00:00+00
# 2455 -79.383542  43.693791      2456   GO-2015864657  2015/05/24 04:00:00+00
#
#       OCC_YEAR OCC_MONTH    OCC_DOW  OCC_DOY  OCC_DAY  ...  DIVISION DEATH
# 2451      2015      July  Wednesday      182        1  ...       D13     0  \
# 2452      2015  December   Thursday      365       31  ...       D31     0
# 2453      2015     March     Monday       82       23  ...       D22     0
# 2454      2015      July   Saturday      192       11  ...       D31     0
# 2455      2015       May     Sunday      144       24  ...       D53     0
#
#      INJURIES  HOOD_158    NEIGHBOURHOOD_158 HOOD_140
# 2451        0       107      Oakwood Village      107  \
# 2452        2       155            Downsview       26
# 2453        0       158            Islington       14
# 2454        1        22           Humbermede       22
# 2455        0        98  Rosedale-Moore Park       98
#
#                     NEIGHBOURHOOD_140 LONG_WGS84  LAT_WGS84  Season
# 2451            Oakwood Village (107) -79.440752  43.697311  Summer
# 2452        Downsview-Roding-CFB (26) -79.482066  43.726636  Winter
# 2453  Islington-City Centre West (14) -79.564077  43.652450  Spring
# 2454                  Humbermede (22) -79.542128  43.750842  Summer
# 2455         Rosedale-Moore Park (98) -79.383542  43.693791  Spring
#
# [5 rows x 22 columns]

# %%
df["DIVISION"].hist()
plt.title("Histogram of DIVISION")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %%
division_count = df['DIVISION'].value_counts()
division_count
# Out:
# DIVISION
# D31    183
# D23    134
# D12     97
# D42     85
# D41     72
# D43     68
# D14     61
# D51     58
# D54     52
# D32     49
# D22     47
# D11     41
# D13     35
# D33     33
# D55     30
# D52     24
# D53     18
# Name: count, dtype: int64

# %%
# Random Forest to predict crime hotspots: “An area or neighborhood with a higher number of criminal records in a certain period of time comparing to other locations.”
# to predict the crime hotspots for the future and use two features the “season” and the “NEIGHBOURHOOD_158” for the prediction.

# %%
# Convert the time to minutes
df['Hour_Min'] = pd.to_datetime(df['OCC_DATE']).dt.hour + pd.to_datetime(df['OCC_DATE']).dt.minute / 60

# Print Crime Counts per Time and DIVISION
df_filtered = df[df['DIVISION'].isin([
    'D11',
    'D12',
    'D13',
    'D14',
    'D22', 
    'D23',
    'D31',
    'D32',
    'D33',
    'D41',
    'D42',
    'D43',
    'D51',
    'D52',
    'D53',
    'D54',
    'D55'])]

# %%
# Processing Function for Features
def cart2polar(x, y):
    dist = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return dist, phi

def preprocessFeatures(dfx):
    
    # Time Feature Engineering
    df = pd.get_dummies(dfx[['OCC_DOW' , 'NEIGHBOURHOOD_158']])
    df['Hour_Min'] = pd.to_datetime(dfx['OCC_DATE']).dt.hour + pd.to_datetime(dfx['OCC_DATE']).dt.minute / 60
    # We add a feature that contains the expontential time
    df['Hour_Min_Exp'] = np.exp(df['Hour_Min'])
    
    df['Day'] = pd.to_datetime(dfx['OCC_DATE']).dt.day
    df['Month'] = pd.to_datetime(dfx['OCC_DATE']).dt.month
    df['Year'] = pd.to_datetime(dfx['OCC_DATE']).dt.year

    month_one_hot_encoded = pd.get_dummies(pd.to_datetime(dfx['OCC_DATE']).dt.month, prefix='Month')
    df = pd.concat([df, month_one_hot_encoded], axis=1, join="inner")
    
    # Convert Coordinates to Polar Coordinates
    df[['X', 'Y']] = dfx[['X', 'Y']] # we maintain the original coordindates as additional features
    df['dist'], df['phi'] = cart2polar(dfx['X'], dfx['Y'])
  

    return df

# %%
# Processing Function for Labels
def encodeLabels(dfx):
    df = pd.DataFrame (columns = [])
    factor = pd.factorize(dfx['DIVISION'])
    return factor


# Encode Labels as Integer
factor = encodeLabels(df)
y_df = factor[0]
labels = list(factor[1])
# for val, i in enumerate(labels):
#     print(val, i)

# %%
# Plot SFD by Lat and Long
df_filtered = df.sample(frac=0.05)  
#df_filtered = df_cleaned[df_cleaned['Category'].isin(['PROSTITUTION', 'VEHICLE THEFT', 'FRAUD'])].sample(frac=0.05) # to filter 

groups = df_filtered.groupby('DIVISION')

fig, ax = plt.subplots(sharex=False, figsize=(20, 12))
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group['X'], group['Y'], marker='.', linestyle='', label=name, alpha=0.9)
ax.legend()
plt.show()

# %%
# Create train_df & test_df
x_df = preprocessFeatures(df).copy()

# Split the data into x_train and y_train data sets
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, train_size=0.7, random_state=0)
x_train
# Out:
#       OCC_DOW_Friday  OCC_DOW_Monday  OCC_DOW_Saturday  OCC_DOW_Sunday
# 3269           False           False             False            True  \
# 2713           False           False             False            True
# 2457           False           False             False            True
# 2717            True           False             False           False
# 3488           False           False             False            True
# ...              ...             ...               ...             ...
# 3484           False           False             False           False
# 3214           False           False             False            True
# 3286            True           False             False           False
# 3010            True           False             False           False
# 3135           False           False             False           False
#
#       OCC_DOW_Thursday  OCC_DOW_Tuesday  OCC_DOW_Wednesday
# 3269             False            False              False  \
# 2713             False            False              False
# 2457             False            False              False
# 2717             False            False              False
# 3488             False            False              False
# ...                ...              ...                ...
# 3484             False            False               True
# 3214             False            False              False
# 3286             False            False              False
# 3010             False            False              False
# 3135              True            False              False
#
#       NEIGHBOURHOOD_158_Agincourt North
# 3269                              False  \
# 2713                              False
# 2457                              False
# 2717                              False
# 3488                              False
# ...                                 ...
# 3484                              False
# 3214                              False
# 3286                              False
# 3010                              False
# 3135                              False
#
#       NEIGHBOURHOOD_158_Agincourt South-Malvern West  NEIGHBOURHOOD_158_Annex
# 3269                                           False                    False  \
# 2713                                           False                    False
# 2457                                           False                    False
# 2717                                           False                    False
# 3488                                           False                    False
# ...                                              ...                      ...
# 3484                                           False                    False
# 3214                                           False                    False
# 3286                                           False                    False
# 3010                                           False                    False
# 3135                                           False                    False
#
#       ...  Month_7  Month_8  Month_9  Month_10  Month_11  Month_12          X
# 3269  ...    False     True    False     False     False     False -79.538412  \
# 2713  ...    False    False    False     False     False     False -79.501498
# 2457  ...    False    False    False     False     False     False -79.536027
# 2717  ...     True    False    False     False     False     False -79.315242
# 3488  ...    False    False    False     False     False      True -79.514576
# ...   ...      ...      ...      ...       ...       ...       ...        ...
# 3484  ...    False    False    False     False     False     False -79.517071
# 3214  ...    False    False    False     False     False     False -79.335991
# 3286  ...    False    False    False     False     False     False -79.369005
# 3010  ...    False    False     True     False     False     False -79.610777
# 3135  ...    False    False    False     False      True     False -79.507192
#
#               Y       dist       phi
# 3269  43.590860  90.700177  2.640249
# 2713  43.741494  90.740325  2.638598
# 2457  43.733419  90.766687  2.638859
# 2717  43.757863  90.585088  2.637449
# 3488  43.699525  90.731562  2.639073
# ...         ...        ...       ...
# 3484  43.754848  90.760406  2.638552
# 3214  43.679723  90.565544  2.638315
# 3286  43.654614  90.582362  2.638733
# 3010  43.733979  90.832465  2.639251
# 3135  43.748467  90.748674  2.638561
#
# [760 rows x 166 columns]

# %%
# Train a single random forest classifier - parameters are a best guess
rf = RandomForestClassifier(max_depth=100, random_state=0, n_estimators = 200)
rf.fit(x_train, y_train.ravel())
y_pred = rf.predict(x_test)

results_log = classification_report(y_test, y_pred)
print(results_log)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82         9
#            1       0.98      0.98      0.98        55
#            2       1.00      0.89      0.94        18
#            3       1.00      1.00      1.00         4
#            4       0.93      1.00      0.97        28
#            5       1.00      1.00      1.00        21
#            6       0.90      1.00      0.95        19
#            7       0.96      0.98      0.97        49
#            8       0.92      0.92      0.92        12
#            9       1.00      0.88      0.93         8
#           10       0.88      0.93      0.90        15
#           11       1.00      1.00      1.00        32
#           12       1.00      0.86      0.92        21
#           13       0.91      1.00      0.95        10
#           14       0.83      1.00      0.91        10
#           15       1.00      1.00      1.00         8
#           16       1.00      0.75      0.86         8
#
#     accuracy                           0.96       327
#    macro avg       0.95      0.94      0.94       327
# weighted avg       0.96      0.96      0.96       327

# %%
# Evaluate the model on the test set
accuracy = rf.score(x_test, y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9571865443425076

# %%
# Get feature importances
feature_importances = rf.feature_importances_

# Create a DataFrame of feature importances
importance_df = pd.DataFrame({'Feature': x_df.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
importance_df = importance_df.sort_values('Importance', ascending=False)

# Display the ranking of divisions based on shooting and firearm discharge activities
print("Ranking of Divisions based on Shooting and Firearm Discharge Activities:")
print(importance_df['Feature'])
# Out:
# Ranking of Divisions based on Shooting and Firearm Discharge Activities:
# 164                                           dist
# 165                                            phi
# 162                                              X
# 163                                              Y
# 147                                            Day
#                           ...
# 14          NEIGHBOURHOOD_158_Bedford Park-Nortown
# 113    NEIGHBOURHOOD_158_South Eglinton-Davisville
# 65            NEIGHBOURHOOD_158_Humewood-Cedarvale
# 36            NEIGHBOURHOOD_158_Dovercourt Village
# 83                      NEIGHBOURHOOD_158_Milliken
# Name: Feature, Length: 166, dtype: object

# %%
# Print a multi-Class Confusion Matrix
cnf_matrix = confusion_matrix(y_test.reshape(-1), y_pred)
df_cm = pd.DataFrame(cnf_matrix, columns=np.unique(y_test), index = np.unique(y_test))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (16,12))
plt.tight_layout()
sns.set(font_scale=1.4) #for label size
sns.heatmap(df_cm, cbar=True, cmap= "inferno", annot=False, fmt='.0f' #, annot_kws={"size": 13}
           )
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
# load the police data by division
df_p = pd.read_csv('/Users/Desktop/project/police_data.csv')
df_p.head()
# Out:
#    Index_  Year       Command_Group     Command_Subunit         Unit
# 0       1  2014  Area Field Command  Area Field Command  22 Division  \
# 1       2  2014  Area Field Command  Area Field Command  22 Division
# 2       3  2014  Area Field Command  Area Field Command  22 Division
# 3       4  2014  Area Field Command  Area Field Command  22 Division
# 4       5  2014  Area Field Command  Area Field Command  22 Division
#
#                        Classification  Count_  ObjectId
# 0                            Civilian      12         1
# 1  Detective Sergeant/ Staff Sergeant       7         2
# 2                           Inspector       1         3
# 3                    Police Constable     165         4
# 4                  Sergeant/Detective      32         5

# %%
# replace the unit value to be the same as the DIVISION data value in df
replace_dict = {'11 Division': 'D11',
                '12 Division': 'D12',
                '13 Division': 'D13',
                '14 Division': 'D14',
                '22 Division': 'D22', 
                '23 Division': 'D23',
                '31 Division': 'D31',
                '32 Division': 'D32',
                '33 Division': 'D33',
                '41 Division': 'D41',
                '42 Division': 'D42',
                '43 Division': 'D43',
                '51 Division': 'D51',
                '52 Division': 'D52',
                '53 Division': 'D53',
                '54 Division': 'D54',
                '55 Division': 'D55'}
df_p['Unit'] = df_p['Unit'].replace(replace_dict)
df_p.head()
# Out:
#    Index_  Year       Command_Group     Command_Subunit Unit
# 0       1  2014  Area Field Command  Area Field Command  D22  \
# 1       2  2014  Area Field Command  Area Field Command  D22
# 2       3  2014  Area Field Command  Area Field Command  D22
# 3       4  2014  Area Field Command  Area Field Command  D22
# 4       5  2014  Area Field Command  Area Field Command  D22
#
#                        Classification  Count_  ObjectId
# 0                            Civilian      12         1
# 1  Detective Sergeant/ Staff Sergeant       7         2
# 2                           Inspector       1         3
# 3                    Police Constable     165         4
# 4                  Sergeant/Detective      32         5
